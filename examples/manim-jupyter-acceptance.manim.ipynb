# %% [markdown]
# # Manim Jupyter acceptance sample
# Typst inline math: $sum_(k=1)^n k = (n(n + 1)) / 2$
#
# Display math: $$ integral_0^infinity e^(-x^2) dif x = sqrt(pi) / 2 $$

# %%
shared_side = 2
def make_shared_square(color):
    return Square(side_length=shared_side, color=color)

# %%
square = make_shared_square(BLUE).to_edge(LEFT)
self.add(square)

# %%
title = TypstMath(
    r"sum_(k=1)^n k = (n(n + 1)) / 2",
    color=MANIM_FOREGROUND,
)
self.play(Write(title))
self.wait(0.5)

# %%
dot = Dot(color=YELLOW)
self.add(dot)
self.play(dot.animate.shift(RIGHT * 3), run_time=1)
self.play(dot.animate.shift(LEFT * 3), run_time=1)

# %%
values = [number ** 2 for number in range(6)]
values
